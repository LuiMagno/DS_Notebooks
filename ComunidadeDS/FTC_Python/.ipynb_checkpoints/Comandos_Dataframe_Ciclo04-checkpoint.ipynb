# %%
import pandas as pd

df = pd.read_csv('C:/Users/lui-m/Documents/GitHub/DS_Notebooks/ComunidadeDS/FTC_Python/datasets/train.csv')
df.head()
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
# 2  0x5d6d     BANGRES19DEL01                   23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4  0x70a2     CHENRES12DEL01                   32                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %% [markdown]
# ### Descobrir as dimensões da planilha de dados

# %%
df.shape
# Out:
# (45593, 20)

# %% [markdown]
# ### Mostrar as X primeiras linhas

# %%
df.head(10)
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
# 2  0x5d6d     BANGRES19DEL01                   23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4  0x70a2     CHENRES12DEL01                   32                     4.6
# 5  0x9bb4      HYDRES09DEL03                   22                     4.8
# 6  0x95b4   RANCHIRES15DEL01                   33                     4.7
# 7  0x9eb2      MYSRES15DEL02                   35                     4.6
# 8  0x1102      HYDRES05DEL02                   22                     4.8
# 9  0xcdcd      DEHRES17DEL01                   36                     4.2
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# ...

# %% [markdown]
# ### Mostrar as X últimas linhas

# %%
df.tail(10)
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 45583  0x5193      MYSRES13DEL02                   36                     4.8
# 45584  0xa333     CHENRES08DEL02                   37                     4.8
# 45585  0xc9ab      KNPRES03DEL01                   30                     4.2
# 45586  0x4e21     BANGRES16DEL03                   28                     4.9
# 45587  0x1178   RANCHIRES16DEL01                   35                     4.2
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# ...

# %% [markdown]
# ### Descobrir os tipos das colunas

# %%
df.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age             object
# Delivery_person_Ratings         object
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weatherconditions               object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries             object
# Festival                        object
# City                            object
# Time_taken(min)                 object
# dtype: object

# %% [markdown]
# ### Lista com valores únicos de uma coluna

# %%
df['Type_of_order'].unique()
# Out:
# array(['Snack ', 'Drinks ', 'Buffet ', 'Meal '], dtype=object)

# %% [markdown]
# ### Ordenar o dataframe baseado em uma coluna

# %%
df.sort_values('Delivery_person_Ratings', ascending=True)
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 25873   0xbb3     CHENRES15DEL03                   15                       1
# 29664  0x137e      MYSRES19DEL02                   15                       1
# 21222   0x3fc     BANGRES16DEL02                   15                       1
# 10900  0x1b49      MUMRES14DEL02                   15                       1
# 44881   0x8d4     CHENRES02DEL02                   15                       1
# ...        ...                ...                 ...                     ...
# 38546   0x6e8     INDORES15DEL02                 NaN                     NaN
# 38534   0x568      MUMRES04DEL03                 NaN                     NaN
# 38533   0x57c     CHENRES13DEL01                 NaN                     NaN
# 3795    0x60d      MYSRES15DEL02                 NaN                     NaN
# 6911   0x2330     CHENRES02DEL02                 NaN                     NaN
#
# ...

# %% [markdown]
# ### Somar todos os dados de uma coluna

# %%
df['Delivery_person_Ratings'].sum()
# Out:
# '4.94.54.44.74.64.84.74.64.84.24.74.74.34.74.544.24.94.74.14.754.344.554.344.84.84.14.34.93.54.64.94.74.854.94.84.3NaN 4.74.64.94.94.94.854.94.854.84.74.74.64.24.54.74.84.94.454.94.84.94.84.84.64.74.64.84.7NaN 4.74.54.14.64.74.74.84.44.754.64.84.84.654.24.64.74.94.8554.74.74.44.84.84.84.64.34.64.84.34.74.24.64.74.63.84.84.84.84.94.94.6NaN 4.24.84.94.54.94.7NaN 4.64.754.64.94.74.94.84.94.44.64.3NaN 54.24.14.64.64.94.73.94.64.44.64.84.94.84.754.34.844.84.44.94.94.14.84.54.74.34.54.754.64.54.74.64.94.84.7NaN 4.64.84.94.73.94.74.74.64.34.944.14.94.74.74.54.654.854.94.84.74.94.344.53.94.84.74.754.54.14.74.44.84.84.64.954.74.94.74.94.84.44.74.64.84.7NaN 44.64.64.84.74.94.84.84.54.54.64.844.94.74.854.7NaN 4.84.94.94.44.64.94.54.24.2NaN 4.54.74.74.84.94.94.44.94.74.74.74.84.84.54.94.154.74.34.54.94.54.74.14.44.54.93.8NaN 4.94.44.94.94.84.844.54.64.954.854.55NaN 4.63.94.64.74.64.84.84.74.74.24.74.34.84.954.64.64.74.64.94.64.74.94.74.5NaN 54.84.54.44.74.44.64.84.24.64.54.54.94.74.84.8NaN 4.54.
# ...

# %% [markdown]
# ### Média de todas as linhas de uma coluna

# %%
df['Vehicle_condition'].mean()
# Out:
# 1.02335884894611

# %% [markdown]
# ### Converter os tipos de colunas

# %%
# Agora nós podemos tirar a média com a coluna 'Delivery_person_Ratings' convertida para float
df['Delivery_person_Ratings'].astype(float).mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 3
#       1 # Agora nós podemos tirar a média com a coluna 'Delivery_person_Ratings' convertida para float
#       2 df['Delivery_person_Ratings'].astype(float).mean()
# ----> 3 df['Delivery_person_Age'].astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %% [markdown]
# ### Converter texto para datas

# %%
pd.to_datetime(df['Order_Date'], format='%d-%m-%Y')
# Out:
# 0       2022-03-19
# 1       2022-03-25
# 2       2022-03-19
# 3       2022-04-05
# 4       2022-03-26
#            ...
# 45588   2022-03-24
# 45589   2022-02-16
# 45590   2022-03-11
# 45591   2022-03-07
# 45592   2022-03-02
# Name: Order_Date, Length: 45593, dtype: datetime64[ns]

# %%
df.head().dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age             object
# Delivery_person_Ratings         object
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weatherconditions               object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries             object
# Festival                        object
# City                            object
# Time_taken(min)                 object
# dtype: object

# %% [markdown]
# ### Selecionar linhas que não tem 'Delivery_person_Age' = NaN

# %%
df1 = df.copy()

# %%
linhas_selecionadas = df1['Delivery_person_Age'] != 'NaN'
df1 = df.loc[linhas_selecionadas, :].copy()
df1
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
# ...

# %%
df1['Delivery_person_Age'] = df1['Delivery_person_Age'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df1['Delivery_person_Age'] = df1['Delivery_person_Age'].astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...
